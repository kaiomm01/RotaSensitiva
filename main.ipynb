# %% [markdown]
# Importando Bibliotecas

# %%
try:
    import pandas as pd
    print('Tudo certo')
except:
    print('Não foi')
# Out:
# Tudo certo

# %%
arquivo = pd.ExcelFile('Rotativos (1).xlsx')

print(arquivo.sheet_names)
# Out:
# ['Planilha1', 'MP03PrepInfBB', 'MP03PrepInfAG', 'MP03SecInfBB', 'MP03SecSup', 'MP04prepInfBB', 'MP04PrepInfAG', 'MP04SecInfBB', 'Fabricação', 'FabricaçãoMP03', 'FabricaçãoMP04', 'MP04SecSup']

# %% [markdown]
# ## Preditiva

# %%
planilha = "FabricaçãoMP04"
filtro = "MP04"

arquivo = pd.read_excel('Rotativos (1).xlsx', sheet_name=planilha)
arquivo = arquivo[arquivo['Ativo'] == filtro]

dicio = {"ativo":[], "Referência":[]}

for aux in arquivo['Equipamento']:
    dicio['ativo'].append(aux.split())


for aux in arquivo['REFERÊNCIA']:
    dicio['Referência'].append(aux)

# %%
def textopreditiva(ref, ativo, refe):
    if ref == 0:
        print(f"""{ativo[0] + " " + ativo[1]}/ {refe}/Preparação de Massa 

INSPECIONAR.................VIBRAÇÃO E RUÍDO ANORMAL  

Medir Vibração MANCAL LA__________mm/s 

Medir Vibração MANCAL LOA_____________mm/s 

OK ( ) NOK ( ) NR ( ) ________________________________________ 

Verificar Temperatura MANCAL LA____________C° 

Verificar Temperatura MANCAL LOA____________C°  

OK ( ) NOK ( ) NR ( ) ________________________________________ 

Verificar Quanto a ruído anormal, Verificar quanto fixação das bases da bomba OK ( ) NOK ( ) NR ( ) ________________________________________ 

Inspecionar Elemento Elástico quanto a trincas e fixação (Utilizar Estroboscópio Digital) 

OK ( ) NOK ( ) NR ( ) ___________________________________ \n\n\n""")
    elif ref == 1:
        print(f"""{ativo[0]}/{refe}/Preparação de Massa
INSPECIONAR.................VIBRAÇÃO E RUÍDO ANORMAL  

***MOTOR ELÉTRICO  

Medir Vibração ROLAMENTO LA__________mm/s  

Verificar Temperatura ROLAMENTO LA____________C° 

 OK ( ) NOK ( ) NR ( ) ________________________________________ 

Medir Vibração ROLAMENTO LOA_____________mm/s  

Verificar Temperatura ROLAMENTO LOA____________C°  

OK ( ) NOK ( ) NR ( ) ________________________________________ 

Verificar Quanto a ruído anormal, Verificar quanto fixação das bases de fixação  

OK ( ) NOK ( ) NR ( ) ________________________________________ \n\n\n""")
    elif ref == 2:
        if len(ativo) > 1:
            ativo[0] = ativo[0] + " " + ativo[1]
        
        print(f"""{ativo[0]}/ {refe}/Preparação de Massa

INSPECIONAR.................VIBRAÇÃO E RUÍDO ANORMAL  

***MANCAL - A G I T A D O R  

Medir Vibração MANCAL LAR__________mm/s  

Medir Vibração MANCAL LOR_____________mm/s  

OK ( ) NOK ( ) NR ( ) ________________________________________  

Verificar Temperatura MANCAL LAR____________C°  

Verificar Temperatura MANCAL LOR____________C°  

OK ( ) NOK ( ) NR ( ) ________________________________________  

Verificar Quanto a ruído anormal, Verificar quanto fixação das bases da bomba  

OK ( ) NOK ( ) NR ( ) ________________________________________ \n\n\n""")
    elif ref == 3:
        print(f"""{ativo[0]}/ {refe}/Preparação de Massa
INSPECIONAR.................VIBRAÇÃO E RUÍDO ANORMAL
*** R E D U T O R
Medir Vibração ROLAMENTO EIXO ENTRAD LA __________mm/s
Verificar Temperatura ROLAMENTO EIXO ENTRAD LA____________C°
OK ( ) NOK ( ) NR ( ) ________________________________________
Medir Vibração ROLAMENTO EIXO ENTRAD LOA __________mm/s
Verificar Temperatura ROLAMENTO EIXO ENTRAD LOA____________C°
OK ( ) NOK ( ) NR ( ) ________________________________________
Medir Vibração EIXO SAÍDA LA_____________mm/s
Verificar Temperatura EIXO SAÍDA LA____________C°
OK ( ) NOK ( ) NR ( ) ________________________________________
Medir Vibração EIXO SAÍDA LOA_____________mm/s
Verificar Temperatura EIXO SAÍDA LOA____________C°
Verificar Quanto a ruído anormal,
OK ( ) NOK ( ) NR ( ) ________________________________________
Verificar quanto fixação das bases de fixação
OK ( ) NOK ( ) NR ( ) ________________________________________\n\n\n""")
    elif ref == 4:
        print(f"""{ativo[0]}/ {refe}/Secagem
INSPECIONAR.................VIBRAÇÃO E RUÍDO ANORMAL
Medir Vibração MANCAL LA__________mm/s
Medir Vibração MANCAL LOA_____________mm/s
OK ( ) NOK ( ) NR ( ) ________________________________________
Verificar Temperatura MANCAL LA____________C°
Verificar Temperatura MANCAL LOA____________C°
OK ( ) NOK ( ) NR ( ) ________________________________________
Verificar Quanto a ruído anormal,
Verificar quanto fixação das bases da bomba
OK ( ) NOK ( ) NR ( ) ________________________________________\n\n\n""")
    else:
        print("Fora do padrão \n\n\n")

# %%
for ativo, refe in zip(dicio['ativo'], dicio['Referência']):
    if ativo[0] == "BOMBA":
       textopreditiva(0, ativo, refe)
    elif ativo[0] == "MOTOR":
        textopreditiva(1, ativo, refe)
    elif ativo[0] == "AGITADOR":
        textopreditiva(2, ativo, refe)
    elif ativo[0] == "REDUTOR":
        textopreditiva(3, ativo, refe)
    elif ativo[0] == "VENTILADOR":
        textopreditiva(4, ativo, refe)
    else:
        textopreditiva(5, ativo, refe)
# Out:
# AGITADOR 4205/ TANQUE 405/Preparação de Massa
#
# INSPECIONAR.................VIBRAÇÃO E RUÍDO ANORMAL
#
# ***MANCAL - A G I T A D O R
#
# Medir Vibração MANCAL LAR__________mm/s
#
# Medir Vibração MANCAL LOR_____________mm/s
#
# OK ( ) NOK ( ) NR ( ) ________________________________________
#
# Verificar Temperatura MANCAL LAR____________C°
#
# Verificar Temperatura MANCAL LOR____________C°
#
# OK ( ) NOK ( ) NR ( ) ________________________________________
#
# Verificar Quanto a ruído anormal, Verificar quanto fixação das bases da bomba
#
# OK ( ) NOK ( ) NR ( ) ________________________________________
#
#
#
# MOTOR/AGITADOR 4205/Preparação de Massa
# INSPECIONAR.................VIBRAÇÃO E RUÍDO ANORMAL
#
# ***MOTOR ELÉTRICO
#
# Medir Vibração ROLAMENTO LA__________mm/s
#
# Verificar Temperatura ROLAMENTO LA____________C°
#
#  OK ( ) NOK ( ) NR ( ) ________________________________________
#
# Medir Vibração ROLAMENTO LOA_____________mm/s
#
# ...

# %% [markdown]
# ## Sensitiva

# %%
planilha = "FabricaçãoMP03"
filtro = "MP03"

arquivo = pd.read_excel('Rotativos (1).xlsx', sheet_name=planilha)
arquivo = arquivo[arquivo['Ativo'] == filtro]

FiltrarAtivos = arquivo['Equipamento'].str.split().str[0].isin(["BOMBA", "VENTILADOR", "AGITADOR"])
arquivo = arquivo[FiltrarAtivos]

dicio = {"ativo":[], "Referência":[]}

for aux in arquivo['Equipamento']:
    dicio['ativo'].append(aux.split())


for aux in arquivo['REFERÊNCIA']:
    dicio['Referência'].append(aux)

# %%
planilha = "FabricaçãoMP03"
filtro = "MP03"

arquivo = pd.read_excel('Rotativos (1).xlsx', sheet_name=planilha)
arquivo = arquivo[arquivo['Ativo'] == filtro]

FiltrarAtivos = arquivo['Equipamento'].str.split().str[0].isin(["BOMBA", "VENTILADOR", "AGITADOR"])
arquivo = arquivo[FiltrarAtivos]

dicio = {"ativo":[], "Referência":[], "Setor":[]}


#print(arquivo.values)
for aux in arquivo.values:
    print(aux)
    dicio['ativo'].append(aux[4].split())
    dicio['Referência'].append(aux[3])
    dicio['Setor'].append(aux[0] + " " + aux[1] + " " + aux[2])
# Out:
# ['MP03' 'Preparação de massa' 'Inferior' 'TANQUE 02' 'BOMBA 3212']
# ['MP03' 'Preparação de massa' 'Inferior' 'TANQUE 03' 'BOMBA 3223']
# ['MP03' 'Preparação de massa' 'Inferior' 'TANQUE 01' 'AGITADOR 3201']
# ['MP03' 'Preparação de massa' 'Inferior' 'TANQUE 01' 'BOMBA 3222']
# ['MP03' 'Preparação de massa' 'Inferior' 'TANQUE 04' 'AGITADOR 3204']
# ['MP03' 'Preparação de massa' 'Inferior' 'TANQUE 04' 'BOMBA 3224']
# ['MP03' 'Preparação de massa' 'Inferior' 'BOMBA 3224' 'AGITADOR 3207']
# ['MP03' 'Preparação de massa' 'Inferior' 'TANQUE 07' 'BOMBA 3206']
# ['MP03' 'Preparação de massa' 'Inferior' 'TANQUE 08' 'AGITADOR 3208']
# ['MP03' 'Preparação de massa' 'Inferior' 'AGITADOR 3208' 'BOMBA 3241']
# ['MP03' 'Preparação de massa' 'Inferior' 'TANQUE 09' 'AGITADOR 3209']
# ['MP03' 'Preparação de massa' 'Inferior' 'TANQUE 09' 'BOMBA 3242']
# ['MP03' 'Preparação de massa' 'Inferior' 'TANQUE 10' 'AGITADOR 3210']
# ['MP03' 'Preparação de massa' 'Inferior' 'TANQUE 10' 'BOMBA 3243']
# ...

# %%
def textosensitiva(ref, ativo, refe, setor):
    if len(ativo) > 1:
        ativo[0] = ativo[0] + " " + ativo[1]
    
    if ref == 0:
        print(f"""{ativo[0]}/ {refe}/ {setor}
INSPECIONAR.................CORPO DA BOMBA
* HÁ VIBRAÇÃO OU RUÍDO EXCESSIVO? (ANÁLISE SENSITIVA)
OK ( ) NOK ( ) NR ( )
* FIXAÇÃO DA BASE ESTÁ CORRETA?
OK ( ) NOK ( ) NR ( )
* MANOMETRO ENCONTRA-SE OPERATIVO E MARCANDO ADEQUADAMENTE? (SE APLICÁVEL)
OK ( ) NOK ( ) NR ( )
* AS PROTEÇÕES DE MÁQUINAS ESTÃO CONSERVADAS E ATENDENDO AS NORMAS?
OK ( ) NOK ( ) NR ( )
* HÁ VAZAMENTOD NOS FLANGES DE SUCÇÃO OU RECALQUE?
OK ( ) NOK ( ) NR ( )
* HÁ VAZAMENTOS NO SELO MECÂNICO / GAXETA?
OK ( ) NOK ( ) NR ( )
* NÍVEL DE ÓLEO DA BOMBA ESTÁ CORRETO (SE APLICADO)
OK ( ) NOK ( ) NR ( )
* INSPECIONAR ELEMENTO ELÁSTICO QUANTO A TRINCAS E FIXAÇÃO (UTILIZAR ESTROBOSCÓPIO
DIGITAL)
OK ( ) NOK ( ) NR ( )
* VIBRAÇÃO MANCAL LA: ____________________ MM/S (ESPERADO +/-2,5MM/S - ALARME
5,0MM/S)
* TEMPERATURA MANCAL LA:__________________°C (ESPERADO +/-60°C - ALARME 80°C)
* VIBRAÇÃO MANCAL LOA: ____________________ MM/S(ESPERADO +/-2,5MM/S - ALARME
5,0MM/S)
* TEMPERATURA MANCAL LOA:__________________°C (ESPERADO +/-60°C - ALARME 80°C)
* EM CASO DE CONDIÇÕES DE ALAME ABRIR NOTA PARA PREDITIVA AVALIAR CAUSAS
Anomalia/Ação Tomada: _________________________________________________________ \n\n\n""")
    elif ref == 1:
        print(f"""{ativo[0]}/{refe}/ {setor}
INSPECIONAR.................ACIONAMENTO E MANCAIS
* HÁ VIBRAÇÃO OU RUÍDO EXCESSIVO? (ANÁLISE SENSITIVA)
OK ( ) NOK ( ) NR ( )
* FIXAÇÃO AO MOTOR ESTÁ CORRETA?
OK ( ) NOK ( ) NR ( )
* VERIFICAR ALINHAMENTO DA CORREIA E DA POLIA
OK ( ) NOK ( ) NR ( )
* VERIFICAR EXISTÊNCIA DE FOLGA NA CORREIA E POLIA
OK ( ) NOK ( ) NR ( )
* VERIFICAR SE AS PROTEÇÕES ESTÃO FIXADAS CORRETAMENTE E BOAS CONDIÇÕES
OK ( ) NOK ( ) NR ( )
* VIBRAÇÃO MANCAL LA: ____________________ MM/S (ESPERADO +/-2,5MM/S - ALARME
5,0MM/S)
OK ( ) NOK ( ) NR ( )
* TEMPERATURA MANCAL LA:__________________°C (ESPERADO +/-60°C - ALARME 80°C)
OK ( ) NOK ( ) NR ( )
* VIBRAÇÃO MANCAL LOA: ____________________ MM/S (ESPERADO +/-2,5MM/S - ALARME
5,0MM/S)
OK ( ) NOK ( ) NR ( )
* TEMPERATURA MANCAL LOA:__________________°C (ESPERADO +/-60°C - ALARME 80°C)
OK ( ) NOK ( ) NR ( )
* EM CASO DE CONDIÇÕES DE ALAME ABRIR NOTA PARA PREDITIVA AVALIAR CAUSAS
Anomalia/Ação Tomada: _________________________________________________________ \n\n\n""")
    elif ref == 2:
        print(f"""{ativo[0]}/ {refe}/ {setor}
INSPECIONAR.................BASE DE FIXAÇÃO E VENTILADOR
* HÁ VIBRAÇÃO OU RUÍDO EXCESSIVO? (ANÁLISE SENSITIVA)
OK ( ) NOK ( ) NR ( )
* VERIFICAR VISUALMENTE FIXAÇÃO DO MOTOR ESTÁ CORRETA?
OK ( ) NOK ( ) NR ( )
* VERIFICAR EXISTÊNCIA DE TRINCAS NOS DUTOS DE AR E ISOLAMENTO (SE APLICÁVEL)
OK ( ) NOK ( ) NR ( )
* VERIFICAR VISUALMENTE CONDIÇÃO DA BASE DE FIXAÇÃO E PARAFUSOS
OK ( ) NOK ( ) NR ( )
* VERIFICAR ESTADO DE CONSERVAÇÃO E LIMPEZA DOS FILTROS DE AR (SE APLICÁVEL)
OK ( ) NOK ( ) NR ( )
* VERIFICAR VISUALMENTE CONEXÕES DOS DUTOS, DESGATE DOS ELEMENTOS DE VEDAÇÃO
*(SE APLICÁVEL)
OK ( ) NOK ( ) NR ( )
* EM CASO DE CONDIÇÕES DE ALAME ABRIR NOTA PARA PREDITIVA AVALIAR CAUSAS
 \n\n\n""")
    elif ref == 3:
        print(f"""{ativo[0]}/ {refe} / {setor}
INSPECIONAR…………………CARCAÇA, VENTILAÇÃO, MANCAIS, LIGAÇÕES E BASE
HÁ VIBRAÇÃO OU RUÍDO EXCESSIVO? (ANÁLISE SENSITIVA)
OK ( )   NOK ( )   NR ( )
VERIFICAR VISUALMENTE A FIXAÇÃO DO MOTOR (PARAFUSOS, BASE, CALÇOS)
OK ( )   NOK ( )   NR ( )
VERIFICAR TEMPERATURA DO MOTOR / CARCAÇA
OK ( )   NOK ( )   NR ( )
VERIFICAR TEMPERATURA DOS MANCAIS (SE APLICÁVEL)
OK ( )   NOK ( )   NR ( )
VERIFICAR VIBRAÇÃO NOS MANCAIS (SE APLICÁVEL)
OK ( )   NOK ( )   NR ( )
VERIFICAR CONDIÇÃO DA VENTOINHA (QUEBRAS, SUJEIRA, FOLGA)
OK ( )   NOK ( )   NR ( )
VERIFICAR LIMPEZA DAS ALETAS DE VENTILAÇÃO (OBSTRUÇÕES)
OK ( )   NOK ( )   NR ( )
VERIFICAR EXISTÊNCIA DE VAZAMENTOS DE ÓLEO/GRAXA (SE APLICÁVEL)
OK ( )   NOK ( )   NR ( )
VERIFICAR RUÍDOS ANORMAIS NA PARTIDA E NA OPERAÇÃO
OK ( )   NOK ( )   NR ( )
VERIFICAR ALINHAMENTO ENTRE MOTOR E EQUIPAMENTO ACIONADO (VISUAL)
OK ( )   NOK ( )   NR ( )
INSPECIONAR ELEMENTO ELÁSTICO / ACOPLAMENTO QUANTO A TRINCAS E FIXAÇÃO
OK ( )   NOK ( )   NR ( )
VERIFICAR CONDIÇÃO DAS LIGAÇÕES ELÉTRICAS EXTERNAS (APERTO, AQUECIMENTO, ODORES)
OK ( )   NOK ( )   NR ( )
VERIFICAR INTEGRIDADE DA CAIXA DE LIGAÇÃO (TAMPA, PASSA-CABOS, VEDAÇÃO)
OK ( )   NOK ( )   NR ( )
VERIFICAR CONDIÇÃO DAS PROTEÇÕES DO ACIONAMENTO
OK ( )   NOK ( )   NR ( )
VERIFICAR LIMPEZA E CONSERVAÇÃO DO MOTOR (POEIRA, FIBRAS, ACÚMULOS)
OK ( )   NOK ( )   NR ( )""")
    elif ref == 4:
        print(f""" {ativo[0]}/ {refe} / {setor}
              INSPECIONAR…………………CORPO DA BOMBA, MANCAIS, SELOS, ACOPLAMENTO E SISTEMA DE VÁCUO
HÁ VIBRAÇÃO OU RUÍDO EXCESSIVO? (ANÁLISE SENSITIVA)
OK ( )  NOK ( )  NR ( )
VERIFICAR FIXAÇÃO DO MOTOR E DA BOMBA
OK ( )  NOK ( )  NR ( )
VERIFICAR PRESSÃO/VÁCUO INDICADO NOS MANÔMETROS
OK ( )  NOK ( )  NR ( )
VERIFICAR EXISTÊNCIA DE VAZAMENTOS EM FLANGES E JUNÇÕES
OK ( )  NOK ( )  NR ( )
VERIFICAR CONDIÇÃO DOS SELOS MECÂNICOS / GAXETAS
OK ( )  NOK ( )  NR ( )
VERIFICAR TEMPERATURA DOS MANCAIS
OK ( )  NOK ( )  NR ( )
VERIFICAR VIBRAÇÃO DOS MANCAIS
OK ( )  NOK ( )  NR ( )
INSPECIONAR ELEMENTO ELÁSTICO QUANTO A TRINCAS E FIXAÇÃO
OK ( )  NOK ( )  NR ( )
VERIFICAR CONDIÇÃO DO SISTEMA DE SELAGEM (SE ANEL LÍQUIDO)
OK ( )  NOK ( )  NR ( )
VERIFICAR LIMPEZA E CONSERVAÇÃO DO CONJUNTO
OK ( )  NOK ( )  NR ( ) \n\n\n""")
    elif ref == 5:
        print(f"""{ativo[0]}/ {refe} / {setor}
              INSPECIONAR…………………RESERVATÓRIO, GRUPO MOTOR-BOMBA, FILTRO E LINHAS HIDRÁULICAS
HÁ VIBRAÇÃO OU RUÍDO EXCESSIVO? (ANÁLISE SENSITIVA)
OK ( )  NOK ( )  NR ( )
VERIFICAR VISUALMENTE FIXAÇÃO DO MOTOR E DA BOMBA ESTÁ CORRETA
OK ( )  NOK ( )  NR ( )
VERIFICAR NÍVEL DE ÓLEO NO RESERVATÓRIO (SE APLICÁVEL)
OK ( )  NOK ( )  NR ( )
VERIFICAR CONDIÇÃO DO FLUIDO (COR/ODOR/CONTAMINAÇÃO)
OK ( )  NOK ( )  NR ( )
VERIFICAR TEMPERATURA DO ÓLEO HIDRÁULICO
OK ( )  NOK ( )  NR ( )
VERIFICAR PRESSÃO DO SISTEMA (MANÔMETRO/TRANSDUTOR) ESTÁ ADEQUADA
OK ( )  NOK ( )  NR ( )
VERIFICAR CONDIÇÃO DO FILTRO (INDICAÇÃO DE ENTUPIMENTO/VAZÃO)
OK ( )  NOK ( )  NR ( )
VERIFICAR VAZAMENTO EM MANGUEIRAS, CONEXÕES E FLANGES
OK ( )  NOK ( )  NR ( )
VERIFICAR CONDIÇÃO DAS MANGUEIRAS (TRINCAS, BOLHAS, DESGASTE)
OK ( )  NOK ( )  NR ( )
VERIFICAR ALINHAMENTO DO ACOPLAMENTO
OK ( )  NOK ( )  NR ( )
INSPECIONAR ELEMENTO ELÁSTICO QUANTO A TRINCAS E FIXAÇÃO
OK ( )  NOK ( )  NR ( )
VERIFICAR TEMPERATURA DOS MANCAIS (SE APLICÁVEL)
OK ( )  NOK ( )  NR ( )
VERIFICAR VIBRAÇÃO DOS MANCAIS (SE APLICÁVEL)
OK ( )  NOK ( )  NR ( ) \n\n\n""")
    
    elif ref == 6:
        print(f"""{ativo[0]}/ {refe} / {setor}
              INSPECIONAR…………………CARCAÇA, LUBRIFICAÇÃO, ACOPLAMENTO E FIXAÇÃO
HÁ VIBRAÇÃO OU RUÍDO EXCESSIVO? (ANÁLISE SENSITIVA)
OK ( )  NOK ( )  NR ( )
VERIFICAR FIXAÇÃO DO REDUTOR E PARAFUSOS DA BASE
OK ( )  NOK ( )  NR ( )
VERIFICAR NÍVEL DE ÓLEO NO VISORES
OK ( )  NOK ( )  NR ( )
VERIFICAR CONDIÇÃO DO ÓLEO (COR/ODOR/ESPUMA)
OK ( )  NOK ( )  NR ( )
VERIFICAR EXISTÊNCIA DE VAZAMENTOS NA CARCAÇA/RETENTORES
OK ( )  NOK ( )  NR ( )
INSPECIONAR ELEMENTO ELÁSTICO (TRINCAS/FIXAÇÃO)
OK ( )  NOK ( )  NR ( )
VERIFICAR TEMPERATURA DO REDUTOR
OK ( )  NOK ( )  NR ( )
VERIFICAR VIBRAÇÃO EM MANCAIS DO REDUTOR (SE APLICÁVEL)
OK ( )  NOK ( )  NR ( )
VERIFICAR CONDIÇÃO DAS PROTEÇÕES DO ACIONAMENTO
OK ( )  NOK ( )  NR ( )
VERIFICAR ESTADO DA BASE (TRINCAS/DEFORMAÇÕES)
OK ( )  NOK ( )  NR ( ) \n\n\n""")
    
    elif ref == 7:
        print(f"""{ativo[0]}/ {refe} / {setor}
              INSPECIONAR…………………MANCAIS, PEDENTAIS, ROLO E ESTRUTURA
HÁ VIBRAÇÃO OU RUÍDO EXCESSIVO? (ANÁLISE SENSITIVA)
OK ( )  NOK ( )  NR ( )
VERIFICAR TEMPERATURA DOS MANCAIS
OK ( )  NOK ( )  NR ( )
VERIFICAR CONDIÇÃO DOS VISORES DE ÓLEO (SE APLICÁVEL)
OK ( )  NOK ( )  NR ( )
VERIFICAR NÍVEL DE ÓLEO DOS MANCAIS (SE APLICÁVEL)
OK ( )  NOK ( )  NR ( )
VERIFICAR EXISTÊNCIA DE VAZAMENTOS
OK ( )  NOK ( )  NR ( )
VERIFICAR FIXAÇÃO DOS PEDENTAIS E PARAFUSOS
OK ( )  NOK ( )  NR ( )
VERIFICAR ALINHAMENTO VISUAL DO ROLO
OK ( )  NOK ( )  NR ( )
VERIFICAR CONDIÇÃO DO EIXO (OXIDAÇÃO, DESGASTE VISÍVEL)
OK ( )  NOK ( )  NR ( )
VERIFICAR CONDIÇÃO DAS PROTEÇÕES (SE APLICÁVEL)
OK ( )  NOK ( )  NR ( )
VERIFICAR LIMPEZA E CONSERVAÇÃO DO CONJUNTO
OK ( )  NOK ( )  NR ( )\n\n\n""")
    else:
        print("Fora do padrão \n\n\n")

# %%
for ativo, ref, setor in zip(dicio['ativo'], dicio['Referência'], dicio['Setor']):
    if len(ativo) > 1:
        if ativo[0] + ativo[1] == "BOMBADE":
            textosensitiva(4, refe)
            
    else:
        if ativo[0] == "BOMBA":
            textosensitiva(0, ativo, refe, setor)
            
        elif ativo[0] == "AGITADOR":
            textosensitiva(1, ativo, refe, setor)
            
        elif ativo[0] == "VENTILADOR":
            textosensitiva(2, ativo, refe, setor)
            
        elif ativo[0] == "MOTOR":
            textosensitiva(3, refe, setor)
            
        elif ativo[0] == "UNIDADE":
            textosensitiva(5, refe, setor)
            
        elif ativo[0] == "REDUTOR":
            textosensitiva(6, refe, setor)
            
        elif ativo[0] == "ROLO":
            textosensitiva(7, refe, setor)
        
        else:
            textosensitiva(8, ativo, refe, setor)
# Out:
# BOMBA 3212/ TANQUE 02/Secagem
# INSPECIONAR.................CORPO DA BOMBA
# * HÁ VIBRAÇÃO OU RUÍDO EXCESSIVO? (ANÁLISE SENSITIVA)
# OK ( ) NOK ( ) NR ( )
# * FIXAÇÃO DA BASE ESTÁ CORRETA?
# OK ( ) NOK ( ) NR ( )
# * MANOMETRO ENCONTRA-SE OPERATIVO E MARCANDO ADEQUADAMENTE? (SE APLICÁVEL)
# OK ( ) NOK ( ) NR ( )
# * AS PROTEÇÕES DE MÁQUINAS ESTÃO CONSERVADAS E ATENDENDO AS NORMAS?
# OK ( ) NOK ( ) NR ( )
# * HÁ VAZAMENTOD NOS FLANGES DE SUCÇÃO OU RECALQUE?
# OK ( ) NOK ( ) NR ( )
# * HÁ VAZAMENTOS NO SELO MECÂNICO / GAXETA?
# OK ( ) NOK ( ) NR ( )
# * NÍVEL DE ÓLEO DA BOMBA ESTÁ CORRETO (SE APLICADO)
# OK ( ) NOK ( ) NR ( )
# * INSPECIONAR ELEMENTO ELÁSTICO QUANTO A TRINCAS E FIXAÇÃO (UTILIZAR ESTROBOSCÓPIO
# DIGITAL)
# OK ( ) NOK ( ) NR ( )
# * VIBRAÇÃO MANCAL LA: ____________________ MM/S (ESPERADO +/-2,5MM/S - ALARME
# 5,0MM/S)
# * TEMPERATURA MANCAL LA:__________________°C (ESPERADO +/-60°C - ALARME 80°C)
# ...
